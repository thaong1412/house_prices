# %% [markdown]
# ## Exercise

# %% [markdown]
# For this exercise, you will be working with the [House Price Dataset](https://www.kaggle.com/competitions/house-prices-advanced-regression-techniques/code).
#
# Please grab the train.csv file from Kaggle and explore this dataset. You need to perform explroatory data analysis and see if there is any correlation between the variables and analyze the distribution of the dataset. The question is open-ended and basically you're asked to perform EDA.

# %% [markdown]
# 1- Write a summary of your findings in one page (e.g., summary statistics, plots) and submit the pdf file. Therefore, for part 3 of your assignment, you need to submit at least one jupyter notebook file and one pdf file.
#
#
# 2- Push your code and project to github and provide the link to your code here. Ensure that your github project is organized to at least couple of main folders, ensure that you have the README file as well:
#
# - Src
# - Data
# - Docs
# - Results
#
# Read this link for further info:  https://gist.github.com/ericmjl/27e50331f24db3e8f957d1fe7bbbe510

# %% [markdown]
# Github: https://github.com/thaong1412/house_prices.git

# %% [markdown]
# # Import libraries

# %%
import pandas as pd 

import numpy as np

import matplotlib.pyplot as plt

import seaborn as sns

# %% [markdown]
# # Loading data

# %%
train = pd.read_csv("train.csv")

# %%
train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %% [markdown]
# # Checking the distribution of the property's sale price in dollars.

# %%
train["SalePrice"].describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
train[train["SalePrice"] == train["SalePrice"].min()]["YrSold"]
# Out:
# 495    2009
# Name: YrSold, dtype: int64

# %% [markdown]
# The property with the lowest price was sold in 2009 for $34900.

# %%
train[train["SalePrice"] == train["SalePrice"].max()]["YrSold"]
# Out:
# 691    2007
# Name: YrSold, dtype: int64

# %% [markdown]
# The property with the largest price was sold in 2007 for $75500.

# %% [markdown]
# ### Distribution of sale price

# %%
plt.figure(figsize=(10, 6))  

sns.histplot(data = train, x='SalePrice', kde=True, color='skyblue', bins=50)

plt.xlabel("SalePrice")
plt.ylabel("Frequency")
plt.title("Distribution of sale price")

plt.savefig("saleprice.jpg", format="jpeg")

plt.show()

# %% [markdown]
# ### Average house price per year

# %%
# Change the data type of column "YrSold" from int64 to str

train['YrSold'] = train['YrSold'].astype(str)

# %%
price_year = pd.DataFrame(train.groupby("YrSold")["SalePrice"].mean())
price_year.reset_index(inplace = True)

price_year
# Out:
#   YrSold      SalePrice
# 0   2006  182549.458599
# 1   2007  186063.151976
# 2   2008  177360.838816
# 3   2009  179432.103550
# 4   2010  177393.674286

# %%
# Visualization of average price per year

plt.bar(price_year["YrSold"],price_year["SalePrice"])

plt.xlabel("Avergae price")
plt.ylabel("Dollars")
plt.title("Avergae house price per year")

plt.savefig("Avergae price.jpg", format="jpeg")

plt.show()

# %% [markdown]
# ### Average price of different MSSubClass group per year

# %%
grouping_criteria = {
    20: '1 - story',
    30: '1 - story',
    40: '1 - story',
    45: '1 - story',
    50: '1 - story',
    60: '2 - story',
    70: '2 - story',
    75: '2 - story',
    80: 'Split',
    85: 'Split',
    90: 'Duplex/ Family conversion',
    120: '1 & 2 story Pud',
    150: '1 & 2 story Pud',
    160: '1 & 2 story Pud',
    180: '1 & 2 story Pud',
    190: 'Duplex/ Family conversion'
}

# Group the data based on the criteria
train['MSSubClassGroup'] = train['MSSubClass'].map(grouping_criteria)

# %%
price_class_year = train.groupby(["YrSold","MSSubClassGroup"])["SalePrice"].mean().reset_index()

price_class_year
# Out:
#    YrSold            MSSubClassGroup      SalePrice
# 0    2006            1 & 2 story Pud  169949.351351
# 1    2006                  1 - story  167044.270968
# 2    2006                  2 - story  232463.511628
# 3    2006  Duplex/ Family conversion  134012.380952
# 4    2006                      Split  155628.000000
# 5    2007            1 & 2 story Pud  172318.129032
# 6    2007                  1 - story  172012.762712
# 7    2007                  2 - story  236057.070588
# 8    2007  Duplex/ Family conversion  140283.611111
# 9    2007                      Split  157594.444444
# 10   2008            1 & 2 story Pud  188394.432432
# 11   2008                  1 - story  160003.296053
# 12   2008                  2 - story  213829.059524
# 13   2008  Duplex/ Family conversion  136723.933333
# 14   2008                      Split  163381.250000
# 15   2009            1 & 2 story Pud  155773.800000
# 16   2009                  1 - story  168799.360215
# ...

# %%
sns.lineplot( data = price_class_year, x = "YrSold", y = "SalePrice", hue = "MSSubClassGroup", palette = "Set2")

plt.xlabel("Avergae price")
plt.ylabel("Dollars")
plt.title("Avergae house price per year")

plt.savefig("line chart.jpg", format="jpeg")

plt.show()

# %% [markdown]
# # Calculate the correlation matrix

# %%
# Select only numeric columns
numeric_columns = train.select_dtypes(include=['int64', 'float64'])

correlation_matrix = numeric_columns.corr()

# Filter and display values greater than 0.5
filtered_correlation_matrix = correlation_matrix[(correlation_matrix != 1) & (correlation_matrix > 0.7)]

filtered_correlation_matrix
# Out:
#                Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# Id            NaN         NaN          NaN      NaN          NaN          NaN
# MSSubClass    NaN         NaN          NaN      NaN          NaN          NaN
# LotFrontage   NaN         NaN          NaN      NaN          NaN          NaN
# LotArea       NaN         NaN          NaN      NaN          NaN          NaN
# OverallQual   NaN         NaN          NaN      NaN          NaN          NaN
# OverallCond   NaN         NaN          NaN      NaN          NaN          NaN
# YearBuilt     NaN         NaN          NaN      NaN          NaN          NaN
# YearRemodAdd  NaN         NaN          NaN      NaN          NaN          NaN
# MasVnrArea    NaN         NaN          NaN      NaN          NaN          NaN
# BsmtFinSF1    NaN         NaN          NaN      NaN          NaN          NaN
# BsmtFinSF2    NaN         NaN          NaN      NaN          NaN          NaN
# ...

# %%
# Visualize the correlation matrix using a heatmap
plt.figure(figsize=(12, 10))
sns.heatmap(filtered_correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap')

plt.savefig("heatmap.jpg", format="jpeg")

plt.show()

# %% [markdown]
# # Distribution of the Dataset for Numerical values

# %%
numeric_columns.hist(figsize=(16, 20), bins=50, xlabelsize=8, ylabelsize=8)

plt.savefig("all distributions.jpg", format="jpeg")
